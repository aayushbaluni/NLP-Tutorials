# %%
import spacy
# Out:
# 2023-03-14 17:44:53.862377: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nlp=spacy.blank("en")

doc=nlp("You can change this by going into the NLTK Downloader window and the File->Change Server Index.")

for token in doc:
    print(token)
# Out:
# You
# can
# change
# this
# by
# going
# into
# the
# NLTK
# Downloader
# window
# and
# the
# File->Change
# Server
# Index
# .

# %%
doc[-1]
# Out:
# .

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc[0:-1]
# Out:
# You can change this by going into the NLTK Downloader window and the File->Change Server Index

# %%
token0=doc[0]
token0
# Out:
# You

# %%
type(token0)
# Out:
# spacy.tokens.token.Token

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
# ...

# %%
token0.like_num
# Out:
# False

# %%
with open("Students.txt") as f:
    text=f.readlines()

# %%
text
# Out:
# ['Student Details\n',
#  '\n',
#  'Name   Age   Email\n',
#  '\n',
#  'Ayush   19    abaluni6@gmail.com\n',
#  '\n',
#  'Akhil   20    akhilsingh123@gmail.com\n',
#  '\n',
#  'Suri    21    bhandari123@gmail.com\n',
#  '\n',
#  'Rajesh  24    gurung111@gmail.com\n',
#  '\n',
#  'Saurav  19    negi456@gmail.com']

# %%
text=" ".join(text)

# %%
text
# Out:
# 'Student Details\n \n Name   Age   Email\n \n Ayush   19    abaluni6@gmail.com\n \n Akhil   20    akhilsingh123@gmail.com\n \n Suri    21    bhandari123@gmail.com\n \n Rajesh  24    gurung111@gmail.com\n \n Saurav  19    negi456@gmail.com'

# %%
doc=nlp(text)

# %%
for token in doc:
    if token.like_email:
        print(token.text)
# Out:
# abaluni6@gmail.com
# akhilsingh123@gmail.com
# bhandari123@gmail.com
# gurung111@gmail.com
# negi456@gmail.com

# %%
#adding special cases while spliting text


from spacy.symbols import ORTH

nlp.tokenizer.add_special_case("gimme",[
    {ORTH:"gim"},
    {ORTH:"me"}
])

# %%
#pipeline of nlp

# %%
#because nlp is blank then we have included an pipe element

nlp.pipe_names
# Out:
# []

# %%
#For segmentation

nlp.add_pipe("sentencizer")

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
doc=nlp("Hey this will. Split sentense in two")

# %%
for token in doc.sents:
    print(token)
# Out:
# Hey this will.
# Split sentense in two

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# TODO: Write code here
# Hint: token has an attribute that can be used to detect a url

# %%
#Exercise

# %%
import spacy

# %%
nlp=spacy.blank("en")

# %%
doc=nlp(text)

# %%
doc
# Out:
# Look for data to help you address the question. Governments are good
# sources because data from public research is often freely available. Good
# places to start include http://www.data.gov/, and http://www.science.
# gov/, and in the United Kingdom, http://data.gov.uk/.
# Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
# and the European Social Survey at http://www.europeansocialsurvey.org/.

# %%
links=[token.text for token in doc if token.like_url]

# %%
links
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"

# TODO: Write code here
# Hint: Use token.i for the index of a token and token.is_currency for currency symbol detection

# %%
doc=nlp(transactions)
ans=[]
for token in doc:
    if token.like_num and doc[token.i+1].is_currency:
        ans.append(token.text+doc[token.i+1].text)

# %%
ans
# Out:
# ['two$', '500€']

# %%
#Sacpy pipeline

# %%
nlp=spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
#ner -> name entity recognizer
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
transactions = "Tony gave two $ to Peter, Bruce gave $500  to Steve"

# %%
doc=nlp(transactions)
for token in doc:
    print(token.text+" | "+token.pos_+" | "+token.tag_+" | "+token.lemma_)
# Out:
# Tony | PROPN | NNP | Tony
# gave | VERB | VBD | give
# two | NUM | CD | two
# $ | SYM | $ | $
# to | ADP | IN | to
# Peter | PROPN | NNP | Peter
# , | PUNCT | , | ,
# Bruce | PROPN | NNP | Bruce
# gave | VERB | VBD | give
# $ | SYM | $ | $
# 500 | NUM | CD | 500
#   | SPACE | _SP |
# to | ADP | IN | to
# Steve | PROPN | NNP | Steve

# %%
for ent in doc.ents:
    print(ent.text + " | " + ent.label_)
# Out:
# Tony | PERSON
# two | CARDINAL
# Peter | PERSON
# Bruce | PERSON
# 500 | MONEY
# Steve | PERSON

# %%
from spacy import displacy

displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  gave
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  $ to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter
# ...

# %%
#to add pipe from any other source pipeline

# %%
source=spacy.load("en_core_web_sm")

# %%
nlp=spacy.blank("en")

# %%
nlp.add_pipe("ner",source=source)

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
transactions = "Ayush gave two $ to Peter, Bruce gave $500  to Steve"

# %%
doc=nlp(transactions)
from spacy import displacy

displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ayush
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  gave
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  $ to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter
# ...
